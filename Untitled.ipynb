# %%
import pandas as pd

# Cargar los datos CSV de Disney
disney_data = pd.read_csv('D:/cursos/challenge rockingdata/disney_plus_titles.csv')

# no podia utilizar el archivo de netflix debido a como fueron cargados, me devuelva errores de ParserError: Error tokenizing data. Por eso
#para este caso lo realice para el de disney

# %%
import pandas as pd

# Cargar los datos CSV de Disney
disney_data = pd.read_csv('D:/cursos/challenge rockingdata/disney_plus_titles.csv')

# Define el nombre del archivo de salida en formato CSV estándar
nombre_archivo = 'datos_tabulares.csv'

# Guarda el DataFrame 'disney_data' en un archivo CSV estándar
disney_data.to_csv(nombre_archivo, index=False)

# Donde 'disney_data' es el nombre de tu DataFrame y 'nombre_archivo' es el nombre del archivo de salida en formato CSV estándar.

# %%
#Visualización de las primeras filas de los datos:
disney_data.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
#Estadísticas resumidas:
disney_data.describe()
# Out:
#        release_year
# count   1450.000000
# mean    2003.091724
# std       21.860162
# min     1928.000000
# 25%     1999.000000
# 50%     2011.000000
# 75%     2018.000000
# max     2021.000000

# %%
#Comprobación de valores nulos:
disney_data.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country         219
# date_added        3
# release_year      0
# rating            3
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
#Comprobación de duplicados:
disney_data.duplicated().sum()
# Out:
# 0

# %%
#Problemas identificados y soluciones sugeridas:

#Valores Nulos: Si has encontrado columnas con valores nulos, considera cómo tratarlos. Puedes eliminar las filas con valores nulos usando 'dropna()' 
#o llenarlos con valores apropiados usando 'fillna()'.

#Duplicados: Si has encontrado filas duplicadas, puedes eliminarlos utilizando 'drop_duplicates()' si no son necesarios para tu análisis.

#Tipo de Datos: Verifica si el tipo de datos de cada columna es apropiado. Si es necesario, puedes cambiar el tipo de datos utilizando 'astype()'.
